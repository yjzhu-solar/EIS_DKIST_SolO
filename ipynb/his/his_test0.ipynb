# %%
import sunpy
import sunpy.timeseries as ts
import numpy as np
import astropy.units as u
import astropy.constants as const
from sunpy.io._cdf import read_cdf
import matplotlib.pyplot as plt

# %%
his_20221022 = ts.TimeSeries("../../src/SWA/HIS/solo_L3_swa-his-comp-10min_20221022_V02.cdf")
his_20221020 = ts.TimeSeries("../../src/SWA/HIS/solo_L3_swa-his-comp-10min_20221020_V02.cdf")
his_20221021 = ts.TimeSeries("../../src/SWA/HIS/solo_L3_swa-his-comp-10min_20221021_V02.cdf")
his_20221023 = ts.TimeSeries("../../src/SWA/HIS/solo_L3_swa-his-comp-10min_20221023_V02.cdf")
his_20221024 = ts.TimeSeries("../../src/SWA/HIS/solo_L3_swa-his-comp-10min_20221024_V02.cdf")
his_20221025 = ts.TimeSeries("../../src/SWA/HIS/solo_L3_swa-his-comp-10min_20221025_V02.cdf")
his_20221026 = ts.TimeSeries("../../src/SWA/HIS/solo_L3_swa-his-comp-10min_20221026_V02.cdf")
his_20221018 = ts.TimeSeries("../../src/SWA/HIS/solo_L3_swa-his-comp-10min_20221018_V02.cdf")
his_20221019 = ts.TimeSeries("../../src/SWA/HIS/solo_L3_swa-his-comp-10min_20221019_V02.cdf")

# %%
his_20221022.meta.columns
# Out:
# ['ACCUM_SECONDS',
#  'AZIMUTH_SOURCE',
#  'C5_DENS',
#  'C5_DENS_ERR',
#  'C5_DENS_QF',
#  'C5_SPEED',
#  'C5_SPEED_ERR',
#  'C5_SPEED_QF',
#  'C5_TH_SPEED',
#  'C5_TH_SPEED_ERR',
#  'C5_TH_SPEED_QF',
#  'C6_C4_RATIO',
#  'C6_C4_RATIO_ERR',
#  'C6_C4_RATIO_QF',
#  'C6_C5_RATIO',
#  'C6_C5_RATIO_ERR',
#  'C6_C5_RATIO_QF',
#  'C_AVE_CHARGE',
#  'C_AVE_CHARGE_ERR',
#  'C_AVE_CHARGE_QF',
#  'C_CHARGE_DIST_0',
#  'C_CHARGE_DIST_1',
#  'C_CHARGE_DIST_2',
#  'C_CHARGE_DIST_ERR_0',
#  'C_CHARGE_DIST_ERR_1',
#  'C_CHARGE_DIST_ERR_2',
#  'C_CHARGE_DIST_QF',
#  'C_O_ABUN',
#  'C_O_ABUN_ERR',
#  'C_O_ABUN_QF',
#  'FE10_DENS',
#  'FE10_DENS_ERR',
#  'FE10_DENS_QF',
#  'FE10_SPEED',
#  'FE10_SPEED_ERR',
#  'FE10_SPEED_QF',
#  'FE10_TH_SPEED',
#  'FE10_TH_SPEED_ERR',
#  'FE10_TH_SPEED_QF',
#  'FE_AVE_CHARGE',
#  'FE_AVE_CHARGE_ERR',
#  'FE_AVE_CHARGE_QF',
#  'FE_CHARGE_DIST_0',
#  'FE_CHARGE_DIST_1',
#  'FE_CHARGE_DIST_10',
#  'FE_CHARGE_DIST_11',
#  'FE_CHARGE_DIST_12',
#  'FE_CHARGE_DIST_13',
# ...

# %%
his_20221022.to_dataframe()[["FE_O_ABUN", "FE_O_ABUN_ERR"]]
# Out:
#                             FE_O_ABUN  FE_O_ABUN_ERR
# EPOCH
# 2022-10-22 05:26:06.919200        NaN            NaN
# 2022-10-22 05:32:38.276900   0.137242       0.007958
# 2022-10-22 05:42:38.287000   0.140464       0.008163
# 2022-10-22 05:52:38.293100   0.131864       0.007858
# 2022-10-22 06:02:38.300100   0.144520       0.007968
# ...                               ...            ...
# 2022-10-22 23:12:40.334500   0.126809       0.007398
# 2022-10-22 23:22:40.342600   0.135914       0.008216
# 2022-10-22 23:32:40.349600   0.130749       0.007682
# 2022-10-22 23:42:40.356600   0.129458       0.007507
# 2022-10-22 23:52:40.363800   0.124741       0.007963
#
# [112 rows x 2 columns]

# %%
pas_ll_20221022 = ts.TimeSeries("../../src/SWA/PAS/solo_L2_swa-pas-grnd-mom_20221022_V02.cdf")
pas_ll_20221020 = ts.TimeSeries("../../src/SWA/PAS/solo_L2_swa-pas-grnd-mom_20221020_V02.cdf")
pas_ll_20221021 = ts.TimeSeries("../../src/SWA/PAS/solo_L2_swa-pas-grnd-mom_20221021_V02.cdf")
pas_ll_20221023 = ts.TimeSeries("../../src/SWA/PAS/solo_L2_swa-pas-grnd-mom_20221023_V02.cdf")
pas_ll_20221024 = ts.TimeSeries("../../src/SWA/PAS/solo_L2_swa-pas-grnd-mom_20221024_V02.cdf")
pas_ll_20221025 = ts.TimeSeries("../../src/SWA/PAS/solo_L2_swa-pas-grnd-mom_20221025_V02.cdf")
pas_ll_20221026 = ts.TimeSeries("../../src/SWA/PAS/solo_L2_swa-pas-grnd-mom_20221026_V02.cdf")
pas_ll_20221018 = ts.TimeSeries("../../src/SWA/PAS/solo_L2_swa-pas-grnd-mom_20221018_V02.cdf")
pas_ll_20221019 = ts.TimeSeries("../../src/SWA/PAS/solo_L2_swa-pas-grnd-mom_20221019_V02.cdf")
pas_ll_20221016 = ts.TimeSeries("../../src/SWA/PAS/solo_L2_swa-pas-grnd-mom_20221016_V02.cdf")
pas_ll_20221017 = ts.TimeSeries("../../src/SWA/PAS/solo_L2_swa-pas-grnd-mom_20221017_V02.cdf")
# Out:
# WARNING: SunpyUserWarning: astropy did not recognize units of "Ticks". Assigning dimensionless units. If you think this unit should not be dimensionless, please raise an issue at https://github.com/sunpy/sunpy/issues [sunpy.io._cdf]

# %%
pas_ll_20221022.to_dataframe()
# Out:
#                             Half_interval  Info          N       P_RTN_0  \
# Epoch
# 2022-10-22 04:33:00.625929            0.5     1  25.284533  9.368906e-17
# 2022-10-22 04:33:04.625936            0.5     1  25.899826  6.626980e-17
# 2022-10-22 04:33:08.625943            0.5     1  24.513443  5.855246e-17
# 2022-10-22 04:33:12.625950            0.5     1  26.630980  6.464184e-17
# 2022-10-22 04:33:16.625957            0.5     1  25.153061  5.269072e-17
# ...                                   ...   ...        ...           ...
# 2022-10-22 23:59:40.740938            0.5     0  23.824070  1.177387e-16
# 2022-10-22 23:59:44.740945            0.5     0  23.232887  1.112403e-16
# 2022-10-22 23:59:48.740952            0.5     0  25.115799  1.195567e-16
# 2022-10-22 23:59:52.740959            0.5     0  23.705723  1.136193e-16
# 2022-10-22 23:59:56.740966            0.5     0  24.500448  1.114618e-16
#
#                                  P_RTN_1       P_RTN_2       P_RTN_3  \
# Epoch
# ...

# %%
mag_20221016 = ts.TimeSeries("../../src/MAG/solo_L2_mag-rtn-normal-1-minute_20221016_V01.cdf")
mag_20221017 = ts.TimeSeries("../../src/MAG/solo_L2_mag-rtn-normal-1-minute_20221017_V01.cdf")
mag_20221018 = ts.TimeSeries("../../src/MAG/solo_L2_mag-rtn-normal-1-minute_20221018_V01.cdf")
mag_20221019 = ts.TimeSeries("../../src/MAG/solo_L2_mag-rtn-normal-1-minute_20221019_V01.cdf")
mag_20221020 = ts.TimeSeries("../../src/MAG/solo_L2_mag-rtn-normal-1-minute_20221020_V01.cdf")
mag_20221021 = ts.TimeSeries("../../src/MAG/solo_L2_mag-rtn-normal-1-minute_20221021_V01.cdf")
mag_20221022 = ts.TimeSeries("../../src/MAG/solo_L2_mag-rtn-normal-1-minute_20221022_V01.cdf")
mag_20221023 = ts.TimeSeries("../../src/MAG/solo_L2_mag-rtn-normal-1-minute_20221023_V01.cdf")
mag_20221024 = ts.TimeSeries("../../src/MAG/solo_L2_mag-rtn-normal-1-minute_20221024_V01.cdf")
mag_20221025 = ts.TimeSeries("../../src/MAG/solo_L2_mag-rtn-normal-1-minute_20221025_V01.cdf")
mag_20221026 = ts.TimeSeries("../../src/MAG/solo_L2_mag-rtn-normal-1-minute_20221026_V01.cdf")

# %%
mag_20221018.to_dataframe()
# Out:
#                                  B_RTN_0    B_RTN_1    B_RTN_2  \
# EPOCH
# 2022-10-18 00:00:29.999998211 -32.052544   6.709540  -7.820933
# 2022-10-18 00:01:30.000004693 -33.122009   5.472211  -6.139867
# 2022-10-18 00:02:30.000001117 -32.482677   5.992340  -6.696328
# 2022-10-18 00:03:29.999997541 -32.963440   3.982630  -4.788270
# 2022-10-18 00:04:30.000004023 -32.657852   4.387669  -5.163612
# ...                                  ...        ...        ...
# 2022-10-18 23:55:29.999995976  33.717903 -30.144100  -2.120177
# 2022-10-18 23:56:30.000002458  28.983690 -34.465992   2.658568
# 2022-10-18 23:57:29.999998882  37.341927 -24.234095  -6.558099
# 2022-10-18 23:58:29.999995306  41.781513 -13.467922  -9.974960
# 2022-10-18 23:59:30.000001788  37.420174 -22.172386 -13.115151
#
#                                QUALITY_BITMASK  QUALITY_FLAG  VECTOR_RANGE  \
# EPOCH
# 2022-10-18 00:00:29.999998211              168             2             3
# ...

# %%
fig, (ax1,ax2,ax3,ax4,ax5) = plt.subplots(5,1, figsize=(10,8), layout="constrained", sharex=True)
# ax5_twinx = ax5.twinx()

for his_dataset in [his_20221018, his_20221019, his_20221020, his_20221021,
                    his_20221022, his_20221023, his_20221024, his_20221025, his_20221026]:
    ax1.plot(his_dataset.to_dataframe().index.values, his_dataset.to_dataframe()["FE_O_ABUN"].values,
             color="red", lw=0.5)
    ax1.fill_between(his_dataset.to_dataframe().index.values,
                      (his_dataset.to_dataframe()["FE_O_ABUN"].values - his_dataset.to_dataframe()["FE_O_ABUN_ERR"].values),
                      (his_dataset.to_dataframe()["FE_O_ABUN"].values + his_dataset.to_dataframe()["FE_O_ABUN_ERR"].values),
                      color="red", alpha=0.5)
    
    ax2.plot(his_dataset.to_dataframe().index.values, his_dataset.to_dataframe()["O7_O6_RATIO"].values,
                color="orange", lw=0.5)
    ax2.fill_between(his_dataset.to_dataframe().index.values,
                        (his_dataset.to_dataframe()["O7_O6_RATIO"].values - his_dataset.to_dataframe()["O7_O6_RATIO_ERR"].values),
                        (his_dataset.to_dataframe()["O7_O6_RATIO"].values + his_dataset.to_dataframe()["O7_O6_RATIO_ERR"].values),
                        color="orange", alpha=0.5)
    
def forward(x):
    return x/10**(7.46 - 8.69)

def inverse(x):
    return x*10**(7.46 - 8.69)

ax1_secondary = ax1.secondary_yaxis('right', functions=(forward, inverse))


for pas_dataset in (pas_ll_20221016, pas_ll_20221017, pas_ll_20221018, pas_ll_20221019, pas_ll_20221020, pas_ll_20221021,
                    pas_ll_20221022, pas_ll_20221023, pas_ll_20221024, pas_ll_20221025, pas_ll_20221026):
    ax3.plot(pas_dataset.to_dataframe().index.values, pas_dataset.to_dataframe()["V_RTN_0"].values + pas_dataset.to_dataframe()["V_SOLO_RTN_0"].values,
                color="blue", lw=0.5)   
    # ax3.plot(pas_dataset.to_dataframe().index.values, np.sqrt((pas_dataset.to_dataframe()["V_RTN_0"].values + pas_dataset.to_dataframe()["V_SOLO_RTN_0"].values)**2 + \
    #                                                           (pas_dataset.to_dataframe()["V_RTN_1"].values + pas_dataset.to_dataframe()["V_SOLO_RTN_1"].values)**2 + \
    #                                                           (pas_dataset.to_dataframe()["V_RTN_2"].values + pas_dataset.to_dataframe()["V_SOLO_RTN_2"].values)**2),
    #                                                             color="blue", lw=0.5)
    
    ax4.plot(pas_dataset.to_dataframe().index.values, pas_dataset.to_dataframe()["N"].values,
             color="green", lw=0.5)

for mag_dataset in (mag_20221016, mag_20221017, mag_20221018, mag_20221019, mag_20221020, mag_20221021,
                    mag_20221022, mag_20221023, mag_20221024, mag_20221025, mag_20221026):
    ax5.plot(mag_dataset.to_dataframe().index.values, mag_dataset.to_dataframe()["B_RTN_0"].values,
             color="purple", lw=0.5)
    
    # ax5_twinx.plot(mag_dataset.to_dataframe().index.values, np.sqrt(mag_dataset.to_dataframe()["B_RTN_0"].values**2 + \
    #                                                                  mag_dataset.to_dataframe()["B_RTN_1"].values**2 + \
    #                                                                     mag_dataset.to_dataframe()["B_RTN_2"].values**2),
    #                color="green", lw=0.5)
    
for ax_ in (ax1,ax2,ax3,ax4):
    ax_.tick_params(axis="x", labelbottom=False)
ax5.tick_params(axis="x", rotation=45)

ax1.set_ylabel(r"$\rm [Fe/O]$")
ax1_secondary.set_ylabel(r"$\rm [Fe/O]/[Fe/O]_{phot}$")
ax2.set_ylabel(r"$\rm O^{7+}/O^{6+}$")
ax3.set_ylabel(r"$v_r$ (km/s)")
ax4.set_ylabel(r"$n$ (cm$^{-3}$)")
ax5.set_ylabel(r"$B_{r}$ (nT)")
ax1.axhline(0.13, color="grey", ls="--", alpha=0.5)
ax2.axhline(0.145, color="grey", ls="--", alpha=0.5)

# %%
his_20221022.to_dataframe()
# Out:
#                             ACCUM_SECONDS  AZIMUTH_SOURCE  C5_DENS  \
# EPOCH
# 2022-10-22 05:26:06.919200      63.148800               0      NaN
# 2022-10-22 05:32:38.276900     413.300812               0      NaN
# 2022-10-22 05:42:38.287000     420.587189               0      NaN
# 2022-10-22 05:52:38.293100     416.944000               0      NaN
# 2022-10-22 06:02:38.300100     418.967987               0      NaN
# ...                                   ...             ...      ...
# 2022-10-22 23:12:40.334500     404.395203               0      NaN
# 2022-10-22 23:22:40.342600     404.799988               0      NaN
# 2022-10-22 23:32:40.349600     408.443207               0      NaN
# 2022-10-22 23:42:40.356600     399.132812               0      NaN
# 2022-10-22 23:52:40.363800     280.931213               0      NaN
#
#                             C5_DENS_ERR  C5_DENS_QF  C5_SPEED  C5_SPEED_ERR  \
# EPOCH
# ...

# %%
for column in his_20221022.to_dataframe().columns:
    if not "QF" in column:
        if np.isfinite(his_20221022.to_dataframe()[column].values).any():
            print(column)
# Out:
# ACCUM_SECONDS
# AZIMUTH_SOURCE
# C6_C4_RATIO
# C6_C4_RATIO_ERR
# C6_C5_RATIO
# C6_C5_RATIO_ERR
# C_AVE_CHARGE
# C_AVE_CHARGE_ERR
# C_CHARGE_DIST_0
# C_CHARGE_DIST_1
# C_CHARGE_DIST_2
# C_CHARGE_DIST_ERR_0
# C_CHARGE_DIST_ERR_1
# C_CHARGE_DIST_ERR_2
# FE_AVE_CHARGE
# FE_AVE_CHARGE_ERR
# FE_CHARGE_DIST_0
# FE_CHARGE_DIST_1
# FE_CHARGE_DIST_2
# FE_CHARGE_DIST_3
# FE_CHARGE_DIST_4
# FE_CHARGE_DIST_5
# FE_CHARGE_DIST_6
# FE_CHARGE_DIST_7
# FE_CHARGE_DIST_8
# FE_CHARGE_DIST_9
# FE_CHARGE_DIST_10
# FE_CHARGE_DIST_11
# FE_CHARGE_DIST_12
# FE_CHARGE_DIST_13
# FE_CHARGE_DIST_14
# FE_CHARGE_DIST_ERR_0
# FE_CHARGE_DIST_ERR_1
# FE_CHARGE_DIST_ERR_2
# FE_CHARGE_DIST_ERR_3
# FE_CHARGE_DIST_ERR_4
# FE_CHARGE_DIST_ERR_5
# FE_CHARGE_DIST_ERR_6
# FE_CHARGE_DIST_ERR_7
# FE_CHARGE_DIST_ERR_8
# FE_CHARGE_DIST_ERR_9
# FE_CHARGE_DIST_ERR_10
# FE_CHARGE_DIST_ERR_11
# FE_CHARGE_DIST_ERR_12
# FE_CHARGE_DIST_ERR_13
# FE_CHARGE_DIST_ERR_14
# FE_O_ABUN
# FE_O_ABUN_ERR
# NUMBER_OF_SCANS
# O6_SPEED
# O6_SPEED_ERR
# ...

# %%
fig, (ax1,ax2,ax3,ax4) = plt.subplots(4,1, figsize=(10,6), layout="constrained", sharex=True)
# ax5_twinx = ax5.twinx()

for his_dataset in [his_20221018, his_20221019, his_20221020, his_20221021,
                    his_20221022, his_20221023, his_20221024, his_20221025, his_20221026]:
    ax1.plot(his_dataset.to_dataframe().index.values, his_dataset.to_dataframe()["FE_O_ABUN"].values,
             color="red", lw=0.5)
    ax1.fill_between(his_dataset.to_dataframe().index.values,
                      (his_dataset.to_dataframe()["FE_O_ABUN"].values - his_dataset.to_dataframe()["FE_O_ABUN_ERR"].values),
                      (his_dataset.to_dataframe()["FE_O_ABUN"].values + his_dataset.to_dataframe()["FE_O_ABUN_ERR"].values),
                      color="red", alpha=0.3)
    
    ax2.plot(his_dataset.to_dataframe().index.values, his_dataset.to_dataframe()["O7_O6_RATIO"].values,
                color="orange", lw=0.5)
    ax2.fill_between(his_dataset.to_dataframe().index.values,
                        (his_dataset.to_dataframe()["O7_O6_RATIO"].values - his_dataset.to_dataframe()["O7_O6_RATIO_ERR"].values),
                        (his_dataset.to_dataframe()["O7_O6_RATIO"].values + his_dataset.to_dataframe()["O7_O6_RATIO_ERR"].values),
                        color="orange", alpha=0.3)
    
    ax3.plot(his_dataset.to_dataframe().index.values, his_dataset.to_dataframe()["FE_AVE_CHARGE"].values,
                color="blue", lw=0.5)
    ax3.fill_between(his_dataset.to_dataframe().index.values,
                        (his_dataset.to_dataframe()["FE_AVE_CHARGE"].values - his_dataset.to_dataframe()["FE_AVE_CHARGE_ERR"].values),
                        (his_dataset.to_dataframe()["FE_AVE_CHARGE"].values + his_dataset.to_dataframe()["FE_AVE_CHARGE_ERR"].values),
                        color="blue", alpha=0.3)
    
    ax4.plot(his_dataset.to_dataframe().index.values, his_dataset.to_dataframe()["C6_C5_RATIO"].values,
                color="green", lw=0.5)
    ax4.fill_between(his_dataset.to_dataframe().index.values,
                        (his_dataset.to_dataframe()["C6_C5_RATIO"].values - his_dataset.to_dataframe()["C6_C5_RATIO_ERR"].values),
                        (his_dataset.to_dataframe()["C6_C5_RATIO"].values + his_dataset.to_dataframe()["C6_C5_RATIO_ERR"].values),
                        color="green", alpha=0.3)
    
def forward(x):
    return x/10**(7.46 - 8.69)

def inverse(x):
    return x*10**(7.46 - 8.69)

ax1_secondary = ax1.secondary_yaxis('right', functions=(forward, inverse))

ax1.set_ylabel(r"$\rm [Fe/O]$")
ax1_secondary.set_ylabel(r"$\rm [Fe/O]/[Fe/O]_{phot}$")
ax2.set_ylabel(r"$\rm O^{7+}/O^{6+}$")
ax3.set_ylabel(r"$<Q_{\rm Fe}>$")
ax4.set_ylabel(r"$\rm C^{6+}/C^{5+}$")
ax1.axhline(0.13, color="grey", ls="--", alpha=0.5)
ax2.axhline(0.145, color="grey", ls="--", alpha=0.5)
