# %%
import numpy as np 
import matplotlib.pyplot as plt
import sunpy 
import sunpy.map
from sunpy.coordinates import Helioprojective, propagate_with_solar_surface
from scipy.interpolate import LinearNDInterpolator, NearestNDInterpolator
import eispac
from astropy.visualization import ImageNormalize, AsinhStretch
from aiapy.calibrate import normalize_exposure, register, update_pointing
from astropy.coordinates import SkyCoord
from astropy import units as u
from astropy.wcs import WCS
from astropy import constants as const
from sun_blinker import SunBlinker
from regions import (PolygonSkyRegion,)

# %%
eis_pointing_save = np.load('../../src/EIS/eis_pointing/eis_20221025_201113/pointing_verification/20221025_201113/offsets.npz',allow_pickle=True)

# %%
eis_pointing_x = eis_pointing_save['x']
eis_pointing_y = eis_pointing_save['y']

# %%
eis_pointing_x.shape
# Out:
# (512, 62)

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(8,3.5),layout='constrained')
ax1.step(np.arange(62),eis_pointing_x[380,:],where='mid')
ax2.step(np.arange(62),eis_pointing_y[380,:],where='mid')
fit_x = np.polyfit(np.arange(62),eis_pointing_x[380,:],2)
fit_y = np.polyfit(np.arange(62)[np.r_[0:10,13:49,53:62]],eis_pointing_y[380,np.r_[0:10,13:49,53:62]],2)
ax1.plot(np.arange(62),np.polyval(fit_x,np.arange(62)))
ax2.plot(np.arange(62),np.polyval(fit_y,np.arange(62)))


for ax_ in (ax1,ax2):
    ax_.grid(True)

# %%
plt.imshow(eis_pointing_x,aspect=1/4,origin='lower',interpolation='none')

# %%
plt.imshow(eis_pointing_y,aspect=1/4,origin='lower', interpolation='none')

# %%
eis_pointing_x_fix = np.zeros_like(eis_pointing_x)
eis_pointing_y_fix = np.zeros_like(eis_pointing_y)

# %%
good_x_pos = np.r_[0:10,13:49,53:62]
for ii in range(512):
    fix_x_ = np.polyfit(good_x_pos,eis_pointing_x[ii,good_x_pos],2)
    fix_y_ = np.polyfit(good_x_pos,eis_pointing_y[ii,good_x_pos],2)

    eis_pointing_x_fix[ii,:] = np.polyval(fix_x_,np.arange(62))
    eis_pointing_y_fix[ii,:] = np.polyval(fix_y_,np.arange(62))

# %%
y_interp = np.linspace(eis_pointing_y_fix.min(), eis_pointing_y_fix.max(), eis_pointing_y_fix.shape[0])
x_interp = np.linspace(eis_pointing_x_fix.min(), eis_pointing_x_fix.max(), eis_pointing_x_fix.shape[1])

# %%
eis_195_fitres = eispac.read_fit("../../src/EIS/DHB_007_v2/20221025T2011/eis_20221025_201113.fe_12_195_119.1c-0.fit.h5")
eis_195_intmap = eis_195_fitres.get_map()
# Out:
# Reading fit result from,
#    ../../src/EIS/DHB_007_v2/20221025T2011/eis_20221025_201113.fe_12_195_119.1c-0.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]

# %%
eis_195_intmap.plot()
# Out:
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]

# %%
xi_interp = np.moveaxis(np.array(np.meshgrid(x_interp, y_interp)), 0, -1)
points = (eis_pointing_x_fix.flatten(), eis_pointing_y_fix.flatten())

# %%
eis_int_interp_linear_func = LinearNDInterpolator(points, eis_195_intmap.data.flatten())
eis_int_interp_linear = eis_int_interp_linear_func(xi_interp)

# %%
interp_dx = (x_interp[-1] - x_interp[0])/(x_interp.shape[0] - 1)
interp_dy = (y_interp[-1] - y_interp[0])/(y_interp.shape[0] - 1)
interp_extent = [x_interp.min() - interp_dx/2, x_interp.max() + interp_dx/2, y_interp.min() - interp_dy/2, y_interp.max() + interp_dy/2]

# %%
fig, ax = plt.subplots(figsize=(5,5),layout='constrained')
ax.imshow(eis_int_interp_linear, norm=ImageNormalize(stretch=AsinhStretch()),
          origin='lower', cmap='sdoaia193',interpolation='none',aspect=eis_195_intmap.scale.axis2/eis_195_intmap.scale.axis1,)
ax_twin = ax.twinx()
ax_twin.step(np.arange(62),eis_pointing_y_fix[380,:],where='mid')

# %%
def xy_to_wcs(x,y,data,date_obs,instrument,observatory):
    nx = data.shape[1]
    ny = data.shape[0]
    wcs_header = sunpy.map.make_fitswcs_header(data,
                                               coordinate=SkyCoord(x[nx//2], y[ny//2], unit=u.arcsec,
                                                                             frame="helioprojective", obstime=date_obs,
                                                                             rsun=696000000.0*u.m),
                                                reference_pixel=[nx//2, ny//2]*u.pix,
                                            scale=[np.abs(x[-1] - x[0])/(nx - 1), np.abs(y[-1] - y[0])/(ny - 1)] * u.arcsec/u.pix,
                                            instrument=instrument,
                                            observatory=observatory,
                                            ) 
    return WCS(wcs_header)

# %%
eis_interp_wcs = xy_to_wcs(x_interp, y_interp, eis_int_interp_linear, eis_195_intmap.date_average, 'EIS', 'Hinode')

# %%
eis_195_int_interp_linear_map = sunpy.map.Map(eis_int_interp_linear, eis_interp_wcs)
eis_195_int_interp_linear_map.plot_settings["aspect"] = eis_195_int_interp_linear_map.scale.axis2/eis_195_int_interp_linear_map.scale.axis1
eis_195_int_interp_linear_map.plot_settings["norm"] = ImageNormalize(stretch=AsinhStretch())
eis_195_int_interp_linear_map.plot_settings["cmap"] = 'sdoaia193'

# %%
fig = plt.figure(figsize=(5,5))
ax = plt.subplot(projection=eis_195_int_interp_linear_map)
eis_195_int_interp_linear_map.plot(axes=ax, cmap='sdoaia193', norm=ImageNormalize(stretch=AsinhStretch()))
# Out:
# WARNING: SunpyMetadataWarning: Missing metadata for observer: assuming Earth-based observer.
# For frame 'heliographic_stonyhurst' the following metadata is missing: hglt_obs,dsun_obs,hgln_obs
# For frame 'heliographic_carrington' the following metadata is missing: crln_obs,dsun_obs,crlt_obs
#  [sunpy.map.mapbase]

# %%
eis_195_intmap.meta['date_obs'], eis_195_intmap.meta['date_avg']
# Out:
# ('2022-10-25T20:11:13.000', '2022-10-25T20:43:11.500')

# %%
aia_193_2043 = sunpy.map.Map('../../src/AIA/20221025/193/lvl15/aia.lev1_euv_12s.2022-10-25T204315Z.193.image.fits')
aia_193_2011 = sunpy.map.Map('../../src/AIA/20221025/193/lvl15/aia.lev1_euv_12s.2022-10-25T201115Z.193.image.fits')

# %%
aia_193_2043_repro = aia_193_2043.reproject_to(eis_195_int_interp_linear_map.wcs)
aia_193_2011_repro = aia_193_2011.reproject_to(eis_195_int_interp_linear_map.wcs)

# %%
aia_193_2043_repro.plot_settings["aspect"] = aia_193_2043_repro.scale.axis2/aia_193_2043_repro.scale.axis1
aia_193_2011_repro.plot_settings["aspect"] = aia_193_2011_repro.scale.axis2/aia_193_2011_repro.scale.axis1

# %%
fig = plt.figure(figsize=(10,5))

ax1 = plt.subplot(121,projection=aia_193_2043_repro)
aia_193_2043_repro.plot(axes=ax1, cmap='sdoaia193', norm=ImageNormalize(stretch=AsinhStretch()))
ax1.set_title('AIA 19.3 nm 20:43 UT')

ax2 = plt.subplot(122,projection=eis_195_int_interp_linear_map)
eis_195_int_interp_linear_map.plot(axes=ax2, cmap='sdoaia193', norm=ImageNormalize(stretch=AsinhStretch()))
ax2.set_title('EIS 19.5 nm optimal')

for ax_ in (ax1,ax2):
    aia_193_2043_repro.draw_contours(levels=[90,300,1000], colors='w', axes=ax_,alpha=0.5,lw=0.5)
# Out:
# /home/yjzhu/anaconda3/envs/sunpy/lib/python3.12/site-packages/astropy/visualization/wcsaxes/core.py:257: UserWarning: The following kwargs were not used by contour: 'lw'
#   cset = super().contour(*args, **kwargs)

# %%
fig = plt.figure(figsize=(10,5))

ax1 = plt.subplot(121,projection=aia_193_2011_repro)
aia_193_2011_repro.plot(axes=ax1, cmap='sdoaia193', norm=ImageNormalize(stretch=AsinhStretch()))
ax1.set_title('AIA 19.3 nm 20:11 UT')

ax2 = plt.subplot(122,projection=eis_195_int_interp_linear_map)
eis_195_int_interp_linear_map.plot(axes=ax2, cmap='sdoaia193', norm=ImageNormalize(stretch=AsinhStretch()))
ax2.set_title('EIS 19.5 nm optimal')

for ax_ in (ax1,ax2):
    aia_193_2011_repro.draw_contours(levels=[100,300,1000], colors='w', axes=ax_,alpha=0.5,lw=0.5)
# Out:
# /home/yjzhu/anaconda3/envs/sunpy/lib/python3.12/site-packages/astropy/visualization/wcsaxes/core.py:257: UserWarning: The following kwargs were not used by contour: 'lw'
#   cset = super().contour(*args, **kwargs)

# %%
SunBlinker(eis_195_int_interp_linear_map, aia_193_2043_repro,figsize=(4,5))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img4768f5e58dd64fe1a5702256d1ac4488">
#   <div class="anim-controls">
#     <input id="_anim_slider4768f5e58dd64fe1a5702256d1ac4488" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim4768f5e58dd64fe1a5702256d1ac4488.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim4768f5e58dd64fe1a5702256d1ac4488.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim4768f5e58dd64fe1a5702256d1ac4488.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim4768f5e58dd64fe1a5702256d1ac4488.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim4768f5e58dd64fe1a5702256d1ac4488.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim4768f5e58dd64fe1a5702256d1ac4488.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim4768f5e58dd64fe1a5702256d1ac4488.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim4768f5e58dd64fe1a5702256d1ac4488.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim4768f5e58dd64fe1a5702256d1ac4488.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim4768f5e58dd64fe1a5702256d1ac4488.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select4768f5e58dd64fe1a5702256d1ac4488"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_4768f5e58dd64fe1a5702256d1ac4488"
#              >
#       <label for="_anim_radio1_4768f5e58dd64fe1a5702256d1ac4488">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_4768f5e58dd64fe1a5702256d1ac4488"
#              checked>
#       <label for="_anim_radio2_4768f5e58dd64fe1a5702256d1ac4488">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_4768f5e58dd64fe1a5702256d1ac4488"
#              >
#       <label for="_anim_radio3_4768f5e58dd64fe1a5702256d1ac4488">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4768f5e58dd64fe1a5702256d1ac4488";
#     var slider_id = "_anim_slider4768f5e58dd64fe1a5702256d1ac4488";
#     var loop_select_id = "_anim_loop_select4768f5e58dd64fe1a5702256d1ac4488";
#     var frames = new Array(2);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjkuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/TGe4hAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAEAAElEQV

# %%
SunBlinker(eis_195_int_interp_linear_map, aia_193_2011_repro,figsize=(4,5))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgb5cba3d6bebc4fbe9e587f38c20b384e">
#   <div class="anim-controls">
#     <input id="_anim_sliderb5cba3d6bebc4fbe9e587f38c20b384e" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animb5cba3d6bebc4fbe9e587f38c20b384e.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animb5cba3d6bebc4fbe9e587f38c20b384e.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animb5cba3d6bebc4fbe9e587f38c20b384e.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animb5cba3d6bebc4fbe9e587f38c20b384e.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animb5cba3d6bebc4fbe9e587f38c20b384e.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animb5cba3d6bebc4fbe9e587f38c20b384e.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animb5cba3d6bebc4fbe9e587f38c20b384e.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animb5cba3d6bebc4fbe9e587f38c20b384e.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animb5cba3d6bebc4fbe9e587f38c20b384e.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animb5cba3d6bebc4fbe9e587f38c20b384e.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectb5cba3d6bebc4fbe9e587f38c20b384e"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_b5cba3d6bebc4fbe9e587f38c20b384e"
#              >
#       <label for="_anim_radio1_b5cba3d6bebc4fbe9e587f38c20b384e">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_b5cba3d6bebc4fbe9e587f38c20b384e"
#              checked>
#       <label for="_anim_radio2_b5cba3d6bebc4fbe9e587f38c20b384e">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_b5cba3d6bebc4fbe9e587f38c20b384e"
#              >
#       <label for="_anim_radio3_b5cba3d6bebc4fbe9e587f38c20b384e">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb5cba3d6bebc4fbe9e587f38c20b384e";
#     var slider_id = "_anim_sliderb5cba3d6bebc4fbe9e587f38c20b384e";
#     var loop_select_id = "_anim_loop_selectb5cba3d6bebc4fbe9e587f38c20b384e";
#     var frames = new Array(2);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjkuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/TGe4hAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAEAAElEQV

# %%
def solar_rotation_compensate_xy_interp(x, y, date_start, date_end, date_average):
    nx = x.shape[1]
    ny = y.shape[0]

    x_derot = np.zeros_like(x)
    y_derot = np.zeros_like(y)

    # EIS scans from west to east
    date_grid = np.linspace(date_end, date_start, nx)

    unify_helioprojective_frame = Helioprojective(observer='earth', obstime=date_average,rsun=696000000.0*u.m)


    for ii in range(nx):
        helioprojective_frame_ii = Helioprojective(observer='earth', obstime=date_grid[ii],rsun=696000000.0*u.m)
        coords_ii = SkyCoord(x[:,ii]*u.arcsec, y[:,ii]*u.arcsec, frame=helioprojective_frame_ii)
        with propagate_with_solar_surface(rotation_model='rigid'):
            coords_ii_unified = coords_ii.transform_to(unify_helioprojective_frame)
        x_derot[:,ii] = coords_ii_unified.Tx.to_value(u.arcsec)
        y_derot[:,ii] = coords_ii_unified.Ty.to_value(u.arcsec)
    
    x_interp = np.linspace(x_derot.min(), x_derot.max(), nx)
    y_interp = np.linspace(y_derot.min(), y_derot.max(), ny)

    return x_derot, y_derot, x_interp, y_interp

# %%
eis_pointing_x_derot, eis_pointing_y_derot, x_interp_derot, y_interp_derot = \
    solar_rotation_compensate_xy_interp(eis_pointing_x_fix, eis_pointing_y_fix, eis_195_intmap.date_start, eis_195_intmap.date_end, eis_195_intmap.date_average)

# %%
xi_interp_derot = np.moveaxis(np.array(np.meshgrid(x_interp_derot, y_interp_derot)), 0, -1)
points_derot = (eis_pointing_x_derot.flatten(), eis_pointing_y_derot.flatten())

eis_int_interp_linear_func_derot = LinearNDInterpolator(points_derot, eis_195_intmap.data.flatten())
eis_int_interp_linear_derot = eis_int_interp_linear_func_derot(xi_interp_derot)

interp_dx_derot = (x_interp_derot[-1] - x_interp_derot[0])/(x_interp_derot.shape[0] - 1)
interp_dy_derot = (y_interp_derot[-1] - y_interp_derot[0])/(y_interp_derot.shape[0] - 1)

interp_extent_derot = [x_interp_derot.min() - interp_dx_derot/2, x_interp_derot.max() + interp_dx_derot/2,
                        y_interp_derot.min() - interp_dy_derot/2, y_interp_derot.max() + interp_dy_derot/2]

# %%
fig, ax = plt.subplots(figsize=(5,5),layout='constrained')
ax.imshow(eis_int_interp_linear_derot, extent=interp_extent_derot, norm=ImageNormalize(stretch=AsinhStretch()),
          origin='lower', cmap='sdoaia193',interpolation='none')

# %%
eis_interp_wcs_derot = xy_to_wcs(x_interp_derot, y_interp_derot, eis_int_interp_linear_derot, eis_195_intmap.date_average, 'EIS', 'Hinode')

# %%
eis_195_int_interp_linear_map_derot = sunpy.map.Map(eis_int_interp_linear_derot, eis_interp_wcs_derot)
eis_195_int_interp_linear_map_derot.plot_settings["aspect"] = eis_195_int_interp_linear_map_derot.scale.axis2/eis_195_int_interp_linear_map_derot.scale.axis1
eis_195_int_interp_linear_map_derot.plot_settings["norm"] = ImageNormalize(stretch=AsinhStretch())
eis_195_int_interp_linear_map_derot.plot_settings["cmap"] = 'sdoaia193'

# %%
fig = plt.figure(figsize=(10,5))

ax1 = plt.subplot(121,projection=aia_193_2043_repro)
aia_193_2043_repro.plot(axes=ax1, cmap='sdoaia193', norm=ImageNormalize(stretch=AsinhStretch()))

ax2 = plt.subplot(122,projection=eis_195_int_interp_linear_map_derot)
eis_195_int_interp_linear_map_derot.plot(axes=ax2, cmap='sdoaia193', norm=ImageNormalize(stretch=AsinhStretch()))

for ax_ in (ax1,ax2):
    aia_193_2043_repro.draw_contours(levels=[90,300,1000], colors='w', axes=ax_,alpha=0.5,lw=0.5)
# Out:
# WARNING: SunpyMetadataWarning: Missing metadata for observer: assuming Earth-based observer.
# For frame 'heliographic_stonyhurst' the following metadata is missing: hglt_obs,dsun_obs,hgln_obs
# For frame 'heliographic_carrington' the following metadata is missing: crln_obs,dsun_obs,crlt_obs
#  [sunpy.map.mapbase]
# /home/yjzhu/anaconda3/envs/sunpy/lib/python3.12/site-packages/astropy/visualization/wcsaxes/core.py:257: UserWarning: The following kwargs were not used by contour: 'lw'
#   cset = super().contour(*args, **kwargs)

# %%
SunBlinker(eis_195_int_interp_linear_map_derot, aia_193_2043, reproject=True,figsize=(4,5))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgcfdc450bddd64139aed1f42f1ae38135">
#   <div class="anim-controls">
#     <input id="_anim_slidercfdc450bddd64139aed1f42f1ae38135" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animcfdc450bddd64139aed1f42f1ae38135.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animcfdc450bddd64139aed1f42f1ae38135.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animcfdc450bddd64139aed1f42f1ae38135.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animcfdc450bddd64139aed1f42f1ae38135.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animcfdc450bddd64139aed1f42f1ae38135.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animcfdc450bddd64139aed1f42f1ae38135.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animcfdc450bddd64139aed1f42f1ae38135.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animcfdc450bddd64139aed1f42f1ae38135.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animcfdc450bddd64139aed1f42f1ae38135.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animcfdc450bddd64139aed1f42f1ae38135.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectcfdc450bddd64139aed1f42f1ae38135"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_cfdc450bddd64139aed1f42f1ae38135"
#              >
#       <label for="_anim_radio1_cfdc450bddd64139aed1f42f1ae38135">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_cfdc450bddd64139aed1f42f1ae38135"
#              checked>
#       <label for="_anim_radio2_cfdc450bddd64139aed1f42f1ae38135">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_cfdc450bddd64139aed1f42f1ae38135"
#              >
#       <label for="_anim_radio3_cfdc450bddd64139aed1f42f1ae38135">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgcfdc450bddd64139aed1f42f1ae38135";
#     var slider_id = "_anim_slidercfdc450bddd64139aed1f42f1ae38135";
#     var loop_select_id = "_anim_loop_selectcfdc450bddd64139aed1f42f1ae38135";
#     var frames = new Array(2);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjkuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/TGe4hAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAEAAElEQV

# %%
eis_195_velmap = eis_195_fitres.get_map(measurement='velocity')
# Out:
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]

# %%
eis_195_vel_interp_linear_func_derot = LinearNDInterpolator(points_derot, eis_195_velmap.data.flatten())
eis_195_vel_interp_linear_derot = eis_195_vel_interp_linear_func_derot(xi_interp_derot)

eis_195_vel_interp_nearest_func_derot = NearestNDInterpolator(points_derot, eis_195_velmap.data.flatten())
eis_195_vel_interp_nearest_derot = eis_195_vel_interp_nearest_func_derot(xi_interp_derot)

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(10,5))

ax1.imshow(eis_195_vel_interp_linear_derot, extent=interp_extent_derot, origin='lower', cmap='RdBu_r',interpolation='none',
           norm=ImageNormalize(vmin=-15,vmax=15))

ax1.set_title('Linear Interpolation')

ax2.imshow(eis_195_vel_interp_nearest_derot, extent=interp_extent_derot, origin='lower', cmap='RdBu_r',interpolation='none',
           norm=ImageNormalize(vmin=-15,vmax=15))
ax2.set_title('Nearest Interpolation')
# Out:
# Text(0.5, 1.0, 'Nearest Interpolation')

# %%
eis_195_vel_interp_linear_map_derot = sunpy.map.Map(eis_195_vel_interp_linear_derot, eis_interp_wcs_derot)

# %%
eis_195_vel_interp_linear_map_derot.plot_settings["aspect"] = eis_195_vel_interp_linear_map_derot.scale.axis2/eis_195_vel_interp_linear_map_derot.scale.axis1
eis_195_vel_interp_linear_map_derot.plot_settings["norm"] = ImageNormalize(vmin=-15,vmax=15)
eis_195_vel_interp_linear_map_derot.plot_settings["cmap"] = 'RdBu_r'

# %%
eis_195_vel_interp_linear_map_derot.plot()
# Out:
# WARNING: SunpyMetadataWarning: Missing metadata for observer: assuming Earth-based observer.
# For frame 'heliographic_stonyhurst' the following metadata is missing: hglt_obs,dsun_obs,hgln_obs
# For frame 'heliographic_carrington' the following metadata is missing: crln_obs,dsun_obs,crlt_obs
#  [sunpy.map.mapbase]

# %%
eis_195_widmap = eis_195_fitres.get_map(measurement='width')
# Out:
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]

# %%
eis_195_widmap.plot(vmin=0.03,vmax=0.04)
# Out:
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]

# %%
eis_195_true_width = np.sqrt( (eis_195_widmap.data * np.sqrt(8*np.log(2)))**2 - (eis_195_fitres.meta["slit_width"][:,np.newaxis])**2)
eis_195_v1oe = eis_195_true_width*u.angstrom/np.sqrt(4*np.log(2))*const.c/(195.119*u.angstrom)
vth2 = 2*const.k_B*(10**6.2)*u.K/const.u/55.85
vnth = np.sqrt(eis_195_v1oe**2 - vth2).to(u.km/u.s)
# Out:
# /tmp/ipykernel_12867/1809368226.py:1: RuntimeWarning: invalid value encountered in sqrt
#   eis_195_true_width = np.sqrt( (eis_195_widmap.data * np.sqrt(8*np.log(2)))**2 - (eis_195_fitres.meta["slit_width"][:,np.newaxis])**2)
# /home/yjzhu/anaconda3/envs/sunpy/lib/python3.12/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)

# %%
eis_195_wid_interp_linear_func_derot = LinearNDInterpolator(points_derot, vnth.flatten())
eis_195_wid_interp_linear_derot = eis_195_wid_interp_linear_func_derot(xi_interp_derot)

# %%
fig, ax = plt.subplots(figsize=(5,5),layout='constrained')

ax.imshow(eis_195_wid_interp_linear_derot, extent=interp_extent_derot, origin='lower', cmap='plasma',interpolation='none',
           norm=ImageNormalize(vmin=10,vmax=40))

# %%
eis_195_wid_interp_linear_derot_map = sunpy.map.Map(eis_195_wid_interp_linear_derot, eis_interp_wcs_derot)

eis_195_wid_interp_linear_derot_map.plot_settings["aspect"] = eis_195_wid_interp_linear_derot_map.scale.axis2/eis_195_wid_interp_linear_derot_map.scale.axis1
eis_195_wid_interp_linear_derot_map.plot_settings["norm"] = ImageNormalize(vmin=10,vmax=40)
eis_195_wid_interp_linear_derot_map.plot_settings["cmap"] = 'magma'

# %%
eis_195_wid_interp_linear_derot_map.plot()
# Out:
# WARNING: SunpyMetadataWarning: Missing metadata for observer: assuming Earth-based observer.
# For frame 'heliographic_stonyhurst' the following metadata is missing: hglt_obs,dsun_obs,hgln_obs
# For frame 'heliographic_carrington' the following metadata is missing: crln_obs,dsun_obs,crlt_obs
#  [sunpy.map.mapbase]

# %%
eis_195_int_interp_linear_map_derot.save("../../src/EIS/DHB_007_v2/20221025T2011/sunpymaps/eis_195_intmap_shift.fits",overwrite=True)
eis_195_vel_interp_linear_map_derot.save("../../src/EIS/DHB_007_v2/20221025T2011/sunpymaps/eis_195_velmap_shift.fits",overwrite=True)
eis_195_wid_interp_linear_derot_map.save("../../src/EIS/DHB_007_v2/20221025T2011/sunpymaps/eis_195_widmap_shift.fits",overwrite=True)

# %%
fig = plt.figure(figsize=(3,5),layout='constrained')

ax = plt.subplot(projection=eis_195_vel_interp_linear_map_derot)
eis_195_vel_interp_linear_map_derot.plot(axes=ax, cmap='coolwarm', norm=ImageNormalize(vmin=-15,vmax=15))

ax.set_xlim(0,25)
ax.set_ylim(150,350)

cs_eis_1025 = eis_195_vel_interp_linear_map_derot.draw_contours(levels=[-5,],colors=["purple"],axes=ax,alpha=0.8)

for ii, seg in enumerate(cs_eis_1025.allsegs[0]):
    if np.nanmean(seg, axis=0)[0] > 0 and np.nanmean(seg, axis=0)[0] < 20 and \
        np.nanmean(seg, axis=0)[1] > 150 and np.nanmean(seg, axis=0)[1] < 350:
        ax.text(np.nanmean(seg, axis=0)[0], np.nanmean(seg, axis=0)[1], f'{ii}', color='white', fontsize=10)


plt.subplots_adjust(bottom=0.0)
# Out:
# /tmp/ipykernel_12867/3870804337.py:17: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(bottom=0.0)

# %%
cs_selected_index_1025 = [22]
    
fig = plt.figure(figsize=(7, 5),layout='constrained')
ax = fig.add_subplot(111, projection=eis_195_vel_interp_linear_map_derot)
eis_195_vel_interp_linear_map_derot.plot(axes=ax)
plt.colorbar()

for ii in cs_selected_index_1025:
    ax.plot(*cs_eis_1025.allsegs[0][ii].T, color='red', lw=2)

# %%
cs_skycoords_eis_1025 = [eis_195_vel_interp_linear_map_derot.pixel_to_world(cs_eis_1025.allsegs[0][cs_selected_index_1025[0]][:,0]*u.pix,
                                                    cs_eis_1025.allsegs[0][cs_selected_index_1025[0]][:,1]*u.pix) \
                ]
cs_regions_eis_1025 = [PolygonSkyRegion(vertices=cs_skycoord) for cs_skycoord in cs_skycoords_eis_1025]

# %%
cs_regions_eis_1025[0].to_pixel(eis_195_vel_interp_linear_map_derot.wcs).write('../../sav/regions/eis_1025_east_pixel.reg',overwrite=True)

# %%
fig = plt.figure(figsize=(3,5),layout='constrained')

ax = plt.subplot(projection=eis_195_vel_interp_linear_map_derot)
eis_195_vel_interp_linear_map_derot.plot(axes=ax, cmap='coolwarm', norm=ImageNormalize(vmin=-15,vmax=15))

ax.set_xlim(30,60)
ax.set_ylim(150,350)

cs_eis_1025_fp = eis_195_vel_interp_linear_map_derot.draw_contours(levels=[-5,],colors=["purple"],axes=ax,alpha=0.8)

for ii, seg in enumerate(cs_eis_1025_fp.allsegs[0]):
    if np.nanmean(seg, axis=0)[0] > 30 and np.nanmean(seg, axis=0)[0] < 60 and \
        np.nanmean(seg, axis=0)[1] > 150 and np.nanmean(seg, axis=0)[1] < 350:
        ax.text(np.nanmean(seg, axis=0)[0], np.nanmean(seg, axis=0)[1], f'{ii}', color='white', fontsize=10)

# %%
cs_selected_index_1025_fp = [157]
    
fig = plt.figure(figsize=(7, 5),layout='constrained')
ax = fig.add_subplot(111, projection=eis_195_vel_interp_linear_map_derot)
eis_195_vel_interp_linear_map_derot.plot(axes=ax)
plt.colorbar()

for ii in cs_selected_index_1025_fp:
    ax.plot(*cs_eis_1025.allsegs[0][ii].T, color='red', lw=2)

# %%
cs_skycoords_eis_1025_fp = [eis_195_vel_interp_linear_map_derot.pixel_to_world(cs_eis_1025_fp.allsegs[0][cs_selected_index_1025_fp[0]][:,0]*u.pix,
                                                    cs_eis_1025_fp.allsegs[0][cs_selected_index_1025_fp[0]][:,1]*u.pix) \
                ]
cs_regions_eis_1025_fp = [PolygonSkyRegion(vertices=cs_skycoord) for cs_skycoord in cs_skycoords_eis_1025_fp]

# %%
cs_regions_eis_1025_fp[0].to_pixel(eis_195_vel_interp_linear_map_derot.wcs).write('../../sav/regions/eis_1025_fp_pixel.reg',overwrite=True)

# %%
fig = plt.figure(figsize=(3,5),layout='constrained')

ax = plt.subplot(projection=eis_195_vel_interp_linear_map_derot)
eis_195_vel_interp_linear_map_derot.plot(axes=ax, cmap='coolwarm', norm=ImageNormalize(vmin=-15,vmax=15))

ax.set_xlim(10,60)
ax.set_ylim(150,350)

cs_eis_1025_moss = eis_195_vel_interp_linear_map_derot.draw_contours(levels=[5,],colors=["purple"],axes=ax,alpha=0.8)

for ii, seg in enumerate(cs_eis_1025_moss.allsegs[0]):
    if np.nanmean(seg, axis=0)[0] > 10 and np.nanmean(seg, axis=0)[0] < 60 and \
        np.nanmean(seg, axis=0)[1] > 150 and np.nanmean(seg, axis=0)[1] < 350:
        ax.text(np.nanmean(seg, axis=0)[0], np.nanmean(seg, axis=0)[1], f'{ii}', color='white', fontsize=10)

# %%
fig = plt.figure(figsize=(3,5),layout='constrained')

ax = plt.subplot(projection=eis_195_vel_interp_linear_map_derot)
eis_195_int_interp_linear_map_derot.plot(axes=ax)

ax.set_xlim(10,60)
ax.set_ylim(150,350)

cs_eis_1025_moss = eis_195_vel_interp_linear_map_derot.draw_contours(levels=[5,],colors=["purple"],axes=ax,alpha=0.8)

for ii, seg in enumerate(cs_eis_1025_moss.allsegs[0]):
    if np.nanmean(seg, axis=0)[0] > 10 and np.nanmean(seg, axis=0)[0] < 60 and \
        np.nanmean(seg, axis=0)[1] > 150 and np.nanmean(seg, axis=0)[1] < 350:
        ax.text(np.nanmean(seg, axis=0)[0], np.nanmean(seg, axis=0)[1], f'{ii}', color='white', fontsize=10)

# %%
cs_selected_index_1025_moss = [139,129]
    
fig = plt.figure(figsize=(7, 5),layout='constrained')
ax = fig.add_subplot(111, projection=eis_195_vel_interp_linear_map_derot)
eis_195_vel_interp_linear_map_derot.plot(axes=ax)
plt.colorbar()

for ii in cs_selected_index_1025_moss:
    ax.plot(*cs_eis_1025_moss.allsegs[0][ii].T, color='red', lw=2)

# %%
cs_skycoords_eis_1025_moss = [eis_195_vel_interp_linear_map_derot.pixel_to_world(cs_eis_1025_moss.allsegs[0][cs_selected_index_1025_moss_][:,0]*u.pix,
                                                    cs_eis_1025_moss.allsegs[0][cs_selected_index_1025_moss_][:,1]*u.pix) \
                              for cs_selected_index_1025_moss_ in cs_selected_index_1025_moss]
cs_regions_eis_1025_moss = [PolygonSkyRegion(vertices=cs_skycoord) for cs_skycoord in cs_skycoords_eis_1025_moss]

# %%
for ii, cs_region in enumerate(cs_regions_eis_1025_moss):
    cs_region.to_pixel(eis_195_vel_interp_linear_map_derot.wcs).write(f'../../sav/regions/eis_1025_moss_pixel_{ii}.reg',overwrite=True)

# %%
fig = plt.figure(figsize=(7, 5),layout='constrained')
ax = fig.add_subplot(111, projection=eis_195_vel_interp_linear_map_derot)
eis_195_vel_interp_linear_map_derot.plot(axes=ax)
plt.colorbar()

cs_regions_eis_1025_moss[0].to_pixel(eis_195_vel_interp_linear_map_derot.wcs).plot(ax=ax, edgecolor='#C1328E', lw=1.5,alpha=0.8)
cs_regions_eis_1025_moss[1].to_pixel(eis_195_vel_interp_linear_map_derot.wcs).plot(ax=ax, edgecolor='#C1328E', lw=1.5,alpha=0.8)

# %%
aia_171_map = sunpy.map.Map("../../src/AIA/20221025/171/lvl15/aia.lev1_euv_12s.2022-10-25T204327Z.171.image.fits")
aia_171_map_crop = aia_171_map.submap(eis_195_vel_interp_linear_map_derot.bottom_left_coord, 
                                      top_right=eis_195_vel_interp_linear_map_derot.top_right_coord)

# %%
fig = plt.figure(figsize=(7, 5),layout='constrained')
ax = fig.add_subplot(111, projection=aia_171_map_crop)
aia_171_map_crop.plot(axes=ax)

cs_regions_eis_1025_moss[0].to_pixel(aia_171_map_crop.wcs).plot(ax=ax, edgecolor='#C1328E', lw=1.5,alpha=0.8)
cs_regions_eis_1025_moss[1].to_pixel(aia_171_map_crop.wcs).plot(ax=ax, edgecolor='#C1328E', lw=1.5,alpha=0.8)
