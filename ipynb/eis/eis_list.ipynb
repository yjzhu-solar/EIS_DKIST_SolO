# %%
import numpy 
import matplotlib.pyplot as plt
import pandas as pd
# import juanfit

# %%
eis_list_file = "../../src/EIS/eis_obs_list.xlsx"

# %%
eis_list_df = pd.read_excel(eis_list_file, sheet_name="Sheet1")
eis_list_df
# Out:
#              obs_start             obs_end  texp              stud_acr  des  \
# 0  2022-10-19 18:26:00 2022-10-19 22:37:00    10  HH_Flare+AR_180x152H  NaN
# 1  2022-10-20 03:44:00 2022-10-20 04:47:00    60            DHB_007_v2  NaN
# 2  2022-10-20 07:05:00 2022-10-20 11:05:00    10  HH_Flare+AR_180x152H  NaN
# 3  2022-10-20 18:54:00 2022-10-20 20:03:00    10  HH_Flare+AR_180x152H  NaN
# 4  2022-10-20 23:43:00 2022-10-21 02:12:00    60            DHB_007_v2  NaN
# 5  2022-10-21 03:15:00 2022-10-21 05:12:00    10  HH_Flare+AR_180x152H  NaN
# 6  2022-10-21 06:12:00 2022-10-21 17:14:00    10  HH_Flare+AR_180x152H  NaN
# 7  2022-10-21 18:14:00 2022-10-21 22:41:00    10  HH_Flare+AR_180x152H  NaN
# 8  2022-10-22 06:30:00 2022-10-22 07:35:00    60            DHB_007_v2  NaN
# 9  2022-10-22 08:08:00 2022-10-22 10:43:00    10  HH_Flare+AR_180x152H  NaN
# 10 2022-10-22 11:18:00 2022-10-22 17:48:00    10  HH_Flare+AR_180x152H  NaN
# 11 2022-10-22 18:34:00 2022-10-22 19:27:00    10  HH_Flare+AR_180x152H  NaN
# 12 2022-10-22 21:40:00 2022-10-23 00:20:00    60            DHB_007_v2  NaN
# 13 2022-10-23 00:44:00 2022-10-23 04:39:00    10             EL_DHB_01  NaN
# 14 2022-10-23 07:05:00 2022-10-23 17:56:00    10  HH_Flare+AR_180x152H  NaN
# 15 2022-10-23 19:01:00 2022-10-23 19:49:00    10  HH_Flare+AR_180x152H  NaN
# 16 2022-10-23 20:38:00 2022-10-23 23:19:00    60            DHB_007_v2  NaN
# 17 2022-10-23 23:50:00 2022-10-24 00:51:00    40    HPW021VEL260x512v2  NaN
# 18 2022-10-24 01:15:00 2022-10-24 02:16:00    60              Atlas_60  NaN
# 19 2022-10-24 02:49:00 2022-10-24 03:50:00    40    HPW021VEL260x512v2  NaN
# 20 2022-10-24 08:00:00 2022-10-24 17:22:00    10  HH_Flare+AR_180x152H  NaN
# 21 2022-10-24 18:08:00 2022-10-24 22:17:00    10  HH_Flare+AR_180x152H  NaN
# 22 2022-10-25 00:23:00 2022-10-25 02:52:00    60            DHB_007_v2  NaN
# 23 2022-10-25 13:01:00 2022-10-25 16:13:00    10  HH_Flare+AR_180x152H  NaN
# 24 2022-10-25 18:34:00 2022-10-25 19:27:00    10  HH_Flare+AR_180x152H  NaN
# 25 2022-10-25 20:11:00 2022-10-25 22:52:00    60            DHB_007_v2  NaN
# 26 2022-10-25 23:24:00 2022-10-26 03:18:00    10             EL_DHB_01  NaN
# 27 2022-10-26 07:13:00 2022-10-26 09:55:00    60            DHB_007_v2  NaN
# 28 2022-10-26 15:44:00 2022-10-26 16:53:00    10  HH_Flare+AR_180x152H  NaN
# 29 2022-10-26 19:09:00 2022-10-26 23:21:00    10  HH_Flare+AR_180x152H  NaN
# 30 2022-10-27 10:59:00 2022-10-27 15:43:00    10             EL_DHB_01  NaN
# 31 2022-10-28 11:30:00 2022-10-28 12:31:00    40    HPW021VEL260x512v2  NaN
# 32 2022-10-28 13:00:00 2022-10-28 14:02:00    60            DHB_007_v2  NaN
#
#     repeat  fovx  fovy  nx  ny
# 0       48   NaN   NaN NaN NaN
# 1        1   NaN   NaN NaN NaN
# 2       40   NaN   NaN NaN NaN
# 3       13   NaN   NaN NaN NaN
# 4        2   NaN   NaN NaN NaN
# 5       22   NaN   NaN NaN NaN
# 6      124   NaN   NaN NaN NaN
# 7       50   NaN   NaN NaN NaN
# 8        1   NaN   NaN NaN NaN
# 9       25   NaN   NaN NaN NaN
# 10      63   NaN   NaN NaN NaN
# 11      10   NaN   NaN NaN NaN
# 12       2   NaN   NaN NaN NaN
# 13      48   NaN   NaN NaN NaN
# 14      94   NaN   NaN NaN NaN
# 15      10   NaN   NaN NaN NaN
# 16       2   NaN   NaN NaN NaN
# 17       1   NaN   NaN NaN NaN
# 18       1   NaN   NaN NaN NaN
# 19       1   NaN   NaN NaN NaN
# 20      85   NaN   NaN NaN NaN
# 21      33   NaN   NaN NaN NaN
# 22       2   NaN   NaN NaN NaN
# 23      36   NaN   NaN NaN NaN
# 24      10   NaN   NaN NaN NaN
# 25       2   NaN   NaN NaN NaN
# 26      48   NaN   NaN NaN NaN
# 27      60   NaN   NaN NaN NaN
# 28      13   NaN   NaN NaN NaN
# 29      33   NaN   NaN NaN NaN
# 30      58   NaN   NaN NaN NaN
# 31       1   NaN   NaN NaN NaN
# 32       1   NaN   NaN NaN NaN

# %%
fig, ax = plt.subplots(figsize=(10,4),constrained_layout=True)

for ii, row_ in eis_list_df.iterrows():
    ax.axvspan(row_["obs_start"], row_["obs_end"], alpha=0.5, color="gray")

# %%
fig, ax = plt.subplots(figsize=(10,4),constrained_layout=True)

color_dict = {"HH_Flare+AR_180x152H":"grey","DHB_007_v2":"#CB4042",
              "EL_DHB_01":"#89916B","HPW021VEL260x512v2":"#66327C",
              "Atlas_60":"#58B2DC"}

for ii, row_ in eis_list_df.iterrows():
    ax.axvspan(row_["obs_start"], row_["obs_end"], alpha=0.5, color=color_dict[row_["stud_acr"]],
               label=row_["stud_acr"])
    
handles, labels = ax.get_legend_handles_labels()
temp_dict = {k:v for k,v in zip(labels,handles)}
ax.legend(temp_dict.values(), temp_dict.keys(), loc="upper left", bbox_to_anchor=(0,1.04,1,0.1), ncol=5,
          mode="expand", frameon=False)
