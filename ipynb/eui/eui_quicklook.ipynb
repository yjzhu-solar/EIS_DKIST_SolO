# %%
import numpy as np
import matplotlib.pyplot as plt
# import juanfit
import sunpy
import sunpy.map

# %%
EUI_file_path = "../../src/EUI/HRI/euv174/20221019/solo_L2_eui-hrieuv174-image_20221019T190000165_V01.fits"

# %%
EUI_map = sunpy.map.Map(EUI_file_path)

# %%
EUI_map.plot()
